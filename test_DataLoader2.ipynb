-- %%
require 'misc.DataLoader'

loader = DataLoader{h5_file = 'full_test_data_real.h5', json_file = 'full_test_data.json', frame_length = 10}
print('init Dataloader done....\n\n\n')
--print(loader:getSeqLength())
print('get seqlength done....\n\n\n')
--print(loader:getVocabSize())
print('get Vocal Size done...\n\n\n')
--print(loader:getVocab())
print('get whole Vocab done...\n\n\n')

print('get  Batch done....finally......\n\n\n')
print(loader:resetIterator('train'))
print('donkey is ready to ship!!!!')
-- Out:
-- init Dataloader done....
--
--
--
-- get seqlength done....
--
--
--
-- get Vocal Size done...
--
--
--
-- get whole Vocab done...
-- get  Batch done....finally......
--
--
--
--
-- donkey is ready to ship!!!!

-- %%
x = loader:getBatch{batch_size = 16, split = 'train', seq_per_img = 5, frames_per_video = 10}
data = x.images
print(#x.labels)
img = {}
for i = 1, 10 do
  img[i] = data[i][1]
end
print(#img)
itorch.image(img)
-- Out:
--  16
--  80
-- [torch.LongStorage of size 2]
--
-- 10
-- Console does not support images

-- %%
x
-- Out:
-- {
--   labels : LongTensor - size: 16x80
--   images : ByteTensor - size: 10x16x3x256x256
--   bounds :
--     {
--       it_max : 1470
--       wrapped : false
--       it_pos_now : 545
--     }
--   infos :
--     {
--       1 :
--         {
--           file_path : WinaH9SkW9c_11_38
--         }
--       2 :
--         {
--           file_path : LYSPQqUvNO0_43_57
--         }
--       3 :
--         {
--           file_path : gbbRwBZuhzI_26_40
--         }
--       4 :
--         {
--           file_path : 3zrVqwV29V8_69_76
--         }
--       5 :
--         {
--           file_path : uxEhH6MPH28_69_85
--         }
--       6 :
--         {
--           file_path : OCcy9TDRGKo_41_51
--         }
--       7 :
--         {
--           file_path : 05gNigkqfNU_24_32
--         }
--       8 :
--         {
--           file_path : q3I3R_gqy8M_73_79
--         }
--       9 :
--         {
--           file_path : PCXHuseKwDc_17_20
--         }
--       10 :
--         {
--           file_path : H9Oplnr8WcE_24_34
--         }
--     11 :
--         {
--           file_path : NKtfKR4GNjU_0_20
--         }
--       12 :
--         {
--           file_path : 2jkExrrm_sQ_19_25
--         }
--       13 :
--         {
--           file_path : fvBs0xpEZhQ_10_30
--         }
--       14 :
--         {
--           file_path : PBHZtoygOYg_450_465
--         }
--       15 :
--         {
--           file_path : fF89MasBFLw_321_326
--         }
--       16 :
--         {
--           file_path : YJ2aGe7CLBo_25_35
--         }
--     }
-- }
